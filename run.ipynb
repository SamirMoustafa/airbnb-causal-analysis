# %%
import pandas as pd

# %%
from src.preprocessing.clean import airbnb_data_clean
from src.utils import df2graph, plot_graph

# %%
df = pd.read_csv('./data/listings_London.csv')
df.head()
# Out:
#       id                                               name  host_id  \
# 0  13913                Holiday London DB Room Let-on going    54730
# 1  15400                Bright Chelsea  Apartment. Chelsea!    60302
# 2  17402              Superb 3-Bed/2 Bath & Wifi: Trendy W1    67564
# 3  17506  Boutique Chelsea/Fulham Double bed 5-star ensuite    67915
# 4  25023      All-comforts 2-bed flat near Wimbledon tennis   102813
#
#    host_name  neighbourhood_group           neighbourhood  latitude  \
# 0      Alina                  NaN               Islington  51.56802
# 1   Philippa                  NaN  Kensington and Chelsea  51.48796
# 2        Liz                  NaN             Westminster  51.52195
# 3  Charlotte                  NaN  Hammersmith and Fulham  51.47935
# 4     Amanda                  NaN              Wandsworth  51.44687
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -0.11121     Private room     65               1                 21
# 1   -0.16898  Entire home/apt    100              10                 89
# 2   -0.14094  Entire home/apt    300               3                 42
# 3   -0.19743     Private room    150               3                  0
# 4   -0.21874  Entire home/apt     65              21                 35
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2020-02-22               0.18                               2
# 1  2020-03-16               0.71                               1
# 2  2019-11-02               0.38                              15
# 3         NaN                NaN                               2
# 4  2020-03-30               0.70                               1
#
#    availability_365
# 0               359
# 1               232
# 2               307
# 3               362
# 4                15

# %%
df.shape
# Out:
# (86358, 12)

# %%
df = airbnb_data_clean(df)

# %%
df
# Out:
#             name  neighbourhood  latitude  longitude  room_type  price  \
# 0      -6.834579             18  51.56802   -0.11121          2     65
# 1     -33.401047             19  51.48796   -0.16898          0    100
# 2       6.394781             32  51.52195   -0.14094          0    300
# 3      22.999325             12  51.47935   -0.19743          2    150
# 4       0.811026             31  51.44687   -0.21874          0     65
# ...          ...            ...       ...        ...        ...    ...
# 86353  37.133957             19  51.49131   -0.19315          0     97
# 86354  37.134174             19  51.49070   -0.19251          0     87
# 86355  37.133827             19  51.49127   -0.19177          0     97
# 86356   0.720655              6  51.51091   -0.08001          0    270
# 86357   3.267486             32  51.51149   -0.12487          0    310
#
#        minimum_nights  number_of_reviews  last_review  reviews_per_month  \
# 0                   1                 21        100.0               0.18
# 1                  10                 89         77.0               0.71
# 2                   3                 42        212.0               0.38
# 3                   3                  0          NaN                NaN
# 4                  21                 35         63.0               0.70
# ...               ...                ...          ...                ...
# 86353               2                  0          NaN                NaN
# 86354               2                  0          NaN                NaN
# 86355               2                  0          NaN                NaN
# 86356               4                  0          NaN                NaN
# 86357               4                  0          NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   2               359
# 1                                   1               232
# 2                                  15               307
# 3                                   2               362
# 4                                   1                15
# ...                               ...               ...
# 86353                               5                86
# 86354                               5                69
# 86355                               5                86
# 86356                               1               351
# 86357                              72               345
#
# [86358 rows x 12 columns]

# %%
# use correlation for now 
causal_model = df.corr()

# %%
# build the graph
G = df2graph(causal_model, .15)

# %%
plot_graph(G)

# %%
scrape('London')
